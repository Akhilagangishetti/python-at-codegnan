# %%
# Abstraction
from abc import ABC, abstractmethod
class Mobile(ABC):
    @abstractmethod
    def Ram(self):
        pass
    @abstractmethod
    def Rom(self):
        pass
    @abstractmethod
    def Battery(self):
        pass
    # Concrete method
    def about_device(self):
        return "This is mobile"
class Oppo(Mobile):
    def __init__(self, model, oppo_ram, oppo_rom, oppo_battery):
        self.model = model
        self.oppo_ram = oppo_ram
        self.oppo_rom = oppo_rom
        self.oppo_battery = oppo_battery
    def ram(self):
        return f"The Oppo {self.model} have {self.oppo_ram}GB RAM"
    
    def Rom(self):
        return f"The Oppo {self.model} have {self.oppo_rom}GB ROM"
    
    def Battery(self):
        return f"The Oppo {self.model} have {self.oppo_battery}MAH"
    def camera(self, front, back):
        return f"The Oppo {self.model} have {front}MP front camera + {back}Mp back camera"
# m = mobile() # 
reno16 = Oppo("reno16", 16, 256, 5000)
reno15 = Oppo("reno15", 8, 256, 5500)
print(reno_16.ram())
print(reno_16.rom())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 33
#      29         return f"The Oppo {self.model} have {self.oppo_battery}MAH"
#      30     def camera(self, front, back):
#      31         return f"The Oppo {self.model} have {front}MP front camera + {back}Mp back camera"
#      32 # m = mobile() #
# ---> 33 reno16 = Oppo("reno16", 16, 256, 5000)
#      34 reno15 = Oppo("reno15", 8, 256, 5500)
#      35 print(reno_16.ram())
#      36 print(reno_16.rom())
#
# TypeError: Can't instantiate abstract class Oppo without an implementation for abstract method 'Ram'

# %%
# Abstraction
from abc import ABC, abstractmethod

class Mobile(ABC):
    @abstractmethod
    def rom(self):
        pass
    @abstractmethod
    def ram(self):
        pass
    @abstractmethod
    def battery(self):
        pass

# concrete method
    def about_device(self):
        return "This is mobile"
class Oppo(Mobile):
    def __init__(self, model, oppo_ram, oppo_rom, oppo_battery):
        self.model = model
        self.oppo_ram = oppo_ram
        self.oppo_rom = oppo_rom
        self.oppo_battery = oppo_battery

    def ram(self):
        return f"The Oppo {self.model} have {self.oppo_ram} GB RAM"
        
    def rom(self):
        return f"The Oppo {self.model} have {self.oppo_rom} GB ROM"

    def battery(self):
        return f"The Oppo {self.model} have {self.oppo_battery} MAH Battery"

    def camera(self, front, back):
        return f"The Oppo {self.model} have {front} MP front camera & {back} MP back camera"

#m = Mobile() ###Can't instantiate abstract class
reno16=Oppo("reno16",16,256,5000)
reno15=Oppo("reno15", 8, 256, 5500)
print(reno16.about_device())
print(reno16.ram())
print(reno16.rom())
# Out:
# This is mobile
# The Oppo reon16 have 16 GB RAM
# The Oppo reon16 have 256 GB ROM
