# %%
# 
name = "Akhila"
age = 20
# My name Akhila and i am a 20 years old
print("My name " + name + " and i am a " + str(age) + " Years old")
# Out:
# My name Akhila and i am a 20 Years old

# %%
## Output formatting 
# 1. Old Style Formatting (usign comma)
name = "Akhila"
age = 20
marks = [65,98,78,82,91]
# My name Akhila and i am a 20 years old
print("My name " , name , " and i am a " , str(age) , " Years old")
# Out:
# My name  Akhila  and i am a  20  Years old

# %%
# 2. Access Specifiers
# integer - %d
#float - %f
#string - %s
name = "Akhila"
age = 20
marks = [65,98,78,82,91]
# My name Akhila and i am a 20 years old
print("My name %s and i am a %d Years old"%(name,age))
# Out:
# My name Akhila and i am a 20 Years old

# %%
# 3. Dot Format
name = "Akhila"
age = 20
marks = [65,98,78,82,91]
# My name Akhila and i am a 20 years old
print("My name {} and i am a {} Years old".format(name, age))
print("My name {} and i am a {} Years old".format(age, name))
# Out:
# My name Akhila and i am a 20 Years old
# My name 20 and i am a Akhila Years old

# %%
num = int(input())
if num >= 0:
    print(f' {num} is positive')
else:
    print(f' {num} is negative')
# Out:
#  -5
#  -5 is negative

# %%
num = int(input())
if num % 3 == 0:
    print(f' {num} is True')
else:
    print(f' {num} is False')
# Out:
#  6
#  6 is True

# %%
num = int(input())
if num % 5 == 0:
    print(f' {num} is True')
else:
    print(f' {num} is False')
# Out:
#  89
#  89 is False

# %%
# 
num = int(input())
if num % 3 == 0 and num % 5 == 0:
    print(f' {num} divisible with both 3 and 5')
else:
    print(f' {num} not divisible with both 3 and 5')
# Out:
#  25
#  25 not divisible with both 3 and 5

# %%
# check weather the number is multiple of 3
num = int(input())
if num * 3 == 0:
    print(f' {num} is multiple')
else:
    print(f' {num} is Not multiple')
# Out:
#  5
#  5 is Not multiple

# %%
# 
num = int(input())
if num % 3 == 0 and num % 5 == 0:
    print(f' {num} divisible with both 3 and 5')
else:
    print(f' {num} not divisible with both 3 and 5')
# Out:
#  20
#  20 not divisible with both 3 and 5

# %%
num = int(input()) 
val = num ** 0.5
print(val)
if val == int(val):
    print(f' {num} perfect square')
else:
    print(f' {num} not a perfect square')
# Out:
#  23
# 4.795831523312719
#  23 not a perfect square
